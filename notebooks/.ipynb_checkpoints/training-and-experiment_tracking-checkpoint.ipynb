# %% [markdown]
# ## Algorithm training, testing, validation, and experiment tracking

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set() # Revert to matplotlib defaults
plt.rcParams['figure.figsize'] = (14, 10)

# %% [markdown]
# ### Model training and testing

# %%
# import libraries for algorithms traininng, and metrics to judge performance
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# training data
train_df = pd.read_csv('/home/josephitopa/Documents/personal_files/ufuoma/data/cleaned_data/train_data.csv')
X_train = train_df.drop(['Radiation'], axis = 1)
y_train = train_df['Radiation']

# test data
test_df = pd.read_csv('/home/josephitopa/Documents/personal_files/ufuoma/data/cleaned_data/test_data.csv')
X_test = test_df.drop(['Radiation'], axis = 1)
y_test = test_df['Radiation']

# %% [markdown]
# ### Linear Regression

# %%
# Setup the pipeline steps for linear regression
steps = [('scaler', StandardScaler()), ('lr', LinearRegression())]
# Create the pipeline
pipeline_lr = Pipeline(steps)
# Fit the pipeline to the train set
pipeline_lr.fit(X_train, y_train)
# Predict the labels of the test set
y_pred_lr = pipeline_lr.predict(X_test)

# %%
#Evaluating algorithm performance
mse = mean_squared_error(y_test, y_pred_lr, squared = False)

mae = mean_absolute_error(y_test, y_pred_lr)

print('r2_score', r2_score(y_test, y_pred_lr))

print('Root Mean Squared Error: %.2f' % np.sqrt(mse))

print('Root Mean Absolute Error: %.2f' % np.sqrt(mae))
# Out:
# r2_score 0.9825735617808133
# Root Mean Squared Error: 3.25
# Root Mean Absolute Error: 2.79

# %%
#Run the model against the test data presented through a plot
fig, pX = plt.subplots()

pX.scatter(y_test, y_pred_lr, edgecolors = (0, 0, 0))
pX.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'm--', lw = 3)
pX.set_xlabel('Actual solar irradiation')
pX.set_ylabel('Predicted solar irradiation')
pX.set_title(" Linear regression: Verified vs Predicted solar irradiation")
plt.savefig("lr_line_of_fit.jpg")
plt.show()

# %%
sns.jointplot(y_test, y_pred_lr, kind = 'reg')
plt.savefig("lr_jointplot.jpg")
plt.show()
# Out:
# /home/josephitopa/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Random Forest Regressor

# %%
# Setup the pipeline steps for random forest: steps
steps = [('scaler', StandardScaler()), ('rfr', RandomForestRegressor())]
# Create the pipeline: pipeline
pipeline_rfr = Pipeline(steps)
# Fit the pipeline to the train set
pipeline_rfr.fit(X_train, y_train)
# Predict the labels of the test set
y_pred_rfr = pipeline_rfr.predict(X_test)

# %%
# Evaluating algorithm performance
mse_rf = mean_squared_error(y_test, y_pred_rfr, squared=False)

mae_rf = mean_absolute_error(y_test, y_pred_rfr)

print('r2_score', r2_score(y_test, y_pred_rfr))

print('Root Mean Squared Error: %.2f' % np.sqrt(mse_rf))

print('Root Mean Absolute Error: %.2f' % np.sqrt(mae_rf))
# Out:
# r2_score 0.9853759927121374
# Root Mean Squared Error: 3.11
# Root Mean Absolute Error: 2.65

# %%
# Run the model against the test data presented through a plot
fig, pX = plt.subplots()

pX.scatter(y_test, y_pred_rfr, edgecolors = (0, 0, 0))
pX.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'm--', lw = 3)
pX.set_xlabel('Actual solar irradiation')
pX.set_ylabel('Predicted solar irradiation')
pX.set_title(" Random Forest: Verified vs Predicted solar irradiation")
plt.savefig("rfr_line_of_fit.jpg")
plt.show()

# %%
sns.jointplot(y_test, y_pred_rfr, kind = 'reg')
plt.savefig("rfr_jointplot.jpg")
plt.show()
# Out:
# /home/josephitopa/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### GradientBoosting Regressor

# %%
# Setup the pipeline steps: steps
steps = [('scaler', StandardScaler()), ('gbr', GradientBoostingRegressor())]
# Create the pipeline: pipeline
pipeline_gbr = Pipeline(steps)
# Fit the pipeline to the train set
pipeline_gbr.fit(X_train, y_train)
# Predict the labels of the test set
y_pred_gbr = pipeline_gbr.predict(X_test)

# %%
# Evaluating algorithm performance
mse_gr = mean_squared_error(y_test, y_pred_gbr, squared = False)

mae_gr = mean_absolute_error(y_test, y_pred_gbr)

print('r2_score', r2_score(y_test, y_pred_gbr))

print('Root Mean Squared Error: %.2f' % np.sqrt(mse_gr))

print('Root Mean Absolute Error: %.2f' % np.sqrt(mae_gr))
# Out:
# r2_score 0.9820643945937519
# Root Mean Squared Error: 3.28
# Root Mean Absolute Error: 2.76

# %%
# Run the model against the test data presented through a plot
fig, pX = plt.subplots()

pX.scatter(y_test, y_pred_gbr, edgecolors = (0, 0, 0))
pX.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'm--', lw = 3)
pX.set_xlabel('Actual solar irradiation')
pX.set_ylabel('Predicted solar irradiation')
pX.set_title(" Gradient Boost: Verified vs Predicted solar irradiation")
plt.savefig("gbr_line_of_fit.jpg")
plt.show()

# %%
sns.jointplot(y_test, y_pred_gbr, kind = 'reg')
plt.savefig("gbr_jointplot.jpg")
plt.show()
# Out:
# /home/josephitopa/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Model Validation

# %%
# validation data
val_df = pd.read_csv('/home/josephitopa/Documents/personal_files/ufuoma/data/cleaned_data/train_data.csv')
X_val = val_df.drop(['Radiation'], axis = 1)
y_val = val_df['Radiation']

# %%
y_val_lr = pipeline_lr.predict(X_val)
y_val_rfr = pipeline_rfr.predict(X_val)
y_val_gbr = pipeline_gbr.predict(X_val)

# %%
# Evaluating algorithm performance for linear regression
mse_lr_val = mean_squared_error(y_val, y_val_lr, squared = False)

mae_lr_val = mean_absolute_error(y_val, y_val_lr)

print('r2_score', r2_score(y_val, y_val_lr))

print('Linear Regression - Root Mean Squared Error: %.2f' % np.sqrt(mse_lr_val))

print('Linear Regression - Root Mean Absolute Error: %.2f' % np.sqrt(mse_lr_val))
# Out:
# r2_score 0.9845700516657856
# Linear Regression - Root Mean Squared Error: 3.19
# Linear Regression - Root Mean Absolute Error: 3.19

# %%
# Evaluating algorithm performance for random forest regression
mse_rf_val = mean_squared_error(y_val, y_val_rfr, squared = False)

mae_rf_val = mean_absolute_error(y_val, y_val_rfr)

print('r2_score', r2_score(y_val, y_val_rfr))

print('Random Forest - Root Mean Squared Error: %.2f' % np.sqrt(mse_rf_val))

print('Random Forest - Root Mean Absolute Error: %.2f' % np.sqrt(mse_rf_val))
# Out:
# r2_score 0.9980186099080657
# Random Forest - Root Mean Squared Error: 1.91
# Random Forest - Root Mean Absolute Error: 1.91

# %%
# Evaluating algorithm performance for gradient boost regression
mse_gbr_val = mean_squared_error(y_val, y_val_gbr, squared = False)

mae_gbr_val = mean_absolute_error(y_val, y_val_gbr)

print('r2_score', r2_score(y_val, y_val_gbr))

print('Gradient Boost - Root Mean Squared Error: %.2f' % np.sqrt(mse_gbr_val))

print('Gradient Boost - Root Mean Absolute Error: %.2f' % np.sqrt(mae_gbr_val))
# Out:
# r2_score 0.9887386268597359
# Gradient Boost - Root Mean Squared Error: 2.95
# Gradient Boost - Root Mean Absolute Error: 2.51

# %% [markdown]
# ## Experiment tracking with neptune

# %%
# Terminal
# !pip install neptune-notebooks
# jupyter nbextension enable --py neptune-notebooks
# !pip install neptune-client==0.14.2
#!pip install neptune-client neptune-sklearn
# !pip install neptune-sklearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting neptune-client==0.14.2
#   Downloading neptune-client-0.14.2.tar.gz (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.9/300.9 KB 318.1 kB/s eta 0:00:001m300.3 kB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: bravado in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (11.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (8.0.3)
# Requirement already satisfied: future>=0.17.1 in /usr/lib/python3/dist-packages (from neptune-client==0.14.2) (0.18.2)
# Requirement already satisfied: oauthlib>=2.1.0 in /usr/lib/python3/dist-packages (from neptune-client==0.14.2) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (1.3.4)
# Requirement already satisfied: Pillow>=1.1.6 in /usr/lib/python3/dist-packages (from neptune-client==0.14.2) (7.0.0)
# Requirement already satisfied: PyJWT in /usr/lib/python3/dist-packages (from neptune-client==0.14.2) (1.7.1)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (2.26.0)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (1.3.0)
# Requirement already satisfied: six>=1.12.0 in /home/josephitopa/.local/lib/python3.8/site-packages (from neptune-client==0.14.2) (1.15.0)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in /usr/lib/python3/dist-packages (from neptune-client==0.14.2) (0.53.0)
# Requirement already satisfied: GitPython>=2.0.8 in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (3.1.24)
# Requirement already satisfied: boto3>=1.16.0 in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (1.20.26)
# Requirement already satisfied: packaging in /home/josephitopa/.local/lib/python3.8/site-packages (from neptune-client==0.14.2) (21.3)
# Requirement already satisfied: urllib3 in /usr/lib/python3/dist-packages (from neptune-client==0.14.2) (1.25.8)
# Requirement already satisfied: swagger-spec-validator>=2.7.4 in /usr/local/lib/python3.8/dist-packages (from neptune-client==0.14.2) (2.7.4)
# Requirement already satisfied: psutil in /home/josephitopa/.local/lib/python3.8/site-packages (from neptune-client==0.14.2) (5.9.0)
# Requirement already satisfied: botocore<1.24.0,>=1.23.26 in /usr/local/lib/python3.8/dist-packages (from boto3>=1.16.0->neptune-client==0.14.2) (1.23.26)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from boto3>=1.16.0->neptune-client==0.14.2) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /usr/local/lib/python3.8/dist-packages (from boto3>=1.16.0->neptune-client==0.14.2) (0.5.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.8/dist-packages (from GitPython>=2.0.8->neptune-client==0.14.2) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.8/dist-packages (from GitPython>=2.0.8->neptune-client==0.14.2) (3.10.0.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20.0->neptune-client==0.14.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.20.0->neptune-client==0.14.2) (2019.11.28)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.20.0->neptune-client==0.14.2) (2.8)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (5.3.1)
# Requirement already satisfied: jsonschema in /home/josephitopa/.local/lib/python3.8/site-packages (from swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (3.2.0)
# Requirement already satisfied: bravado-core>=5.16.1 in /usr/local/lib/python3.8/dist-packages (from bravado->neptune-client==0.14.2) (5.17.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.8/dist-packages (from bravado->neptune-client==0.14.2) (1.0.3)
# Requirement already satisfied: monotonic in /usr/lib/python3/dist-packages (from bravado->neptune-client==0.14.2) (1.5)
# Requirement already satisfied: python-dateutil in /home/josephitopa/.local/lib/python3.8/site-packages (from bravado->neptune-client==0.14.2) (2.8.2)
# Requirement already satisfied: simplejson in /usr/lib/python3/dist-packages (from bravado->neptune-client==0.14.2) (3.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/josephitopa/.local/lib/python3.8/site-packages (from packaging->neptune-client==0.14.2) (2.4.7)
# Requirement already satisfied: pytz>=2017.3 in /home/josephitopa/.local/lib/python3.8/site-packages (from pandas->neptune-client==0.14.2) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/josephitopa/.local/lib/python3.8/site-packages (from pandas->neptune-client==0.14.2) (1.19.5)
# Requirement already satisfied: jsonref in /usr/local/lib/python3.8/dist-packages (from bravado-core>=5.16.1->bravado->neptune-client==0.14.2) (0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune-client==0.14.2) (5.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/josephitopa/.local/lib/python3.8/site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (20.3.0)
# Requirement already satisfied: setuptools in /home/josephitopa/.local/lib/python3.8/site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (60.10.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/josephitopa/.local/lib/python3.8/site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (0.18.1)
# Requirement already satisfied: jsonpointer>1.13 in /home/josephitopa/.local/lib/python3.8/site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (2.3)
# Requirement already satisfied: webcolors in /home/josephitopa/.local/lib/python3.8/site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (1.11.1)
# Requirement already satisfied: rfc3987 in /home/josephitopa/.local/lib/python3.8/site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (1.3.8)
# Requirement already satisfied: strict-rfc3339 in /home/josephitopa/.local/lib/python3.8/site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune-client==0.14.2) (0.7)
# Building wheels for collected packages: neptune-client
#   Building wheel for neptune-client (setup.py) ... done
#   Created wheel for neptune-client: filename=neptune_client-0.14.2-py2.py3-none-any.whl size=528176 sha256=b8fe136d2aa2dc054a1c91e5df3162425fb69d55bc78c0740e53147e68e6cd30
#   Stored in directory: /home/josephitopa/.cache/pip/wheels/dd/39/c6/b033e4859916c3c56f966b9cb3835982ef3f147b1838972621
# Successfully built neptune-client
# Installing collected packages: neptune-client
# Successfully installed neptune-client-0.14.2

# %%
# import neptune libraries and sklearn integration
import neptune.new as neptune
import neptune.new.integrations.sklearn as npt_utils

run = neptune.init(api_token = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxZGI1ZjU1MC0yMDhkLTQ5NWMtYTQzYy0xOGMzMTBmNGZlMTUifQ==",
                   project = "ufuomarorobi/solar-irradiation-prediction-2022",
                   name = 'predicting-solar-irradiation',
                   source_files = ["training-and-experiment_tracking.ipynb"])
# Out:
# ---------------------------------------------------------------------------
# UnsupportedClientVersion                  Traceback (most recent call last)
# Input In [24], in <cell line: 5>()
#       2 import neptune.new as neptune
#       3 import neptune.new.integrations.sklearn as npt_utils
# ----> 5 run = neptune.init(api_token = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxZGI1ZjU1MC0yMDhkLTQ5NWMtYTQzYy0xOGMzMTBmNGZlMTUifQ==",
#       6                    project = "ufuomarorobi/solar-irradiation-prediction-2022",
#       7                    name = 'predicting-solar-irradiation',
#       8                    source_files = ["training-and-experiment_tracking.ipynb"])
#
# File /usr/local/lib/python3.8/dist-packages/neptune/new/internal/init_run.py:233, in init_run(project, api_token, run, custom_run_id, mode, name, description, tags, source_files, capture_stdout, capture_stderr, capture_hardware_metrics, fail_on_exception, monitoring_namespace, flush_period, proxies, capture_traceback, **kwargs)
#     230 if run and custom_run_id:
#     231     raise NeptuneRunResumeAndCustomIdCollision()
# --> 233 backend = get_backend(mode, api_token=api_token, proxies=proxies)
#     235 if mode == Mode.OFFLINE or mode == Mode.DEBUG:
#     236     project = "offline/project-placeholder"
#
# File /usr/local/lib/python3.8/dist-packages/neptune/new/internal/backends/factory.py:31, in get_backend(mode, api_token, proxies)
#      27 def get_backend(
#      28     mode: Mode, api_token: Optional[str] = None, proxies: Optional[dict] = None
#      29 ) -> NeptuneBackend:
#      30     if mode == Mode.ASYNC:
# ---> 31         return HostedNeptuneBackend(
#      32             credentials=Credentials.from_token(api_token=api_token), proxies=proxies
#      33         )
#      34     elif mode == Mode.SYNC:
#      35         return HostedNeptuneBackend(
#      36             credentials=Credentials.from_token(api_token=api_token), proxies=proxies
#      37         )
#
# File /usr/local/lib/python3.8/dist-packages/neptune/new/internal/backends/hosted_neptune_backend.py:127, in HostedNeptuneBackend.__init__(self, credentials, proxies)
#     124 self.proxies = proxies
#     125 self.missing_features = []
# --> 127 self._http_client, self._client_config = create_http_client_with_auth(
#     128     credentials=credentials, ssl_verify=ssl_verify(), proxies=proxies
#     129 )
#     131 self.backend_client = create_backend_client(
#     132     self._client_config, self._http_client
#     133 )
#     134 self.leaderboard_client = create_leaderboard_client(
#     135     self._client_config, self._http_client
#     136 )
#
# File /usr/local/lib/python3.8/dist-packages/neptune/new/internal/backends/utils.py:318, in cache.<locals>.wrapper(*args, **kwargs)
#     316 args = tuple([HDict(arg) if isinstance(arg, dict) else arg for arg in args])
#     317 kwargs = {k: HDict(v) if isinstance(v, dict) else v for k, v in kwargs.items()}
# --> 318 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/neptune/new/internal/backends/hosted_client.py:148, in create_http_client_with_auth(credentials, ssl_verify, proxies)
#     142 client_config = get_client_config(
#     143     credentials=credentials, ssl_verify=ssl_verify, proxies=proxies
#     144 )
#     146 config_api_url = credentials.api_url_opt or credentials.token_origin_address
# --> 148 verify_client_version(client_config, neptune_client_version)
#     150 endpoint_url = None
#     151 if config_api_url != client_config.api_url:
#
# File /usr/local/lib/python3.8/dist-packages/neptune/new/internal/backends/utils.py:201, in verify_client_version(client_config, version)
#     196 version_with_patch_0 = Version(replace_patch_version(str(version)))
#     197 if (
#     198     client_config.min_compatible_version
#     199     and client_config.min_compatible_version > version
#     200 ):
# --> 201     raise UnsupportedClientVersion(
#     202         version, min_version=client_config.min_compatible_version
#     203     )
#     204 if (
#     205     client_config.max_compatible_version
#     206     and client_config.max_compatible_version < version_with_patch_0
#     207 ):
#     208     raise UnsupportedClientVersion(
#     209         version, max_version=client_config.max_compatible_version
#     210     )
#
# UnsupportedClientVersion:
#
# ----UnsupportedClientVersion-------------------------------------------------------------
#
# Your version of neptune-client (0.14.0) library is not supported by the Neptune server.
#
# Please install neptune-client>=0.14.2
#
# Need help?-> https://docs.neptune.ai/getting-started/getting-help

# %%
# Track files, models, and folders
# Folders
run["cleaned_datasets"].track_files("~/Documents/Projects/update_project/My_Best_Projects/Solar_Energy_Project/datasets/cleaned")
run["raw_datasets"].track_files("~/Documents/Projects/update_project/My_Best_Projects/Solar_Energy_Project/datasets/raw")

# Folder
run["notebooks"].track_files("~/Documents/Projects/update_project/My_Best_Projects/Solar_Energy_Project/notebooks/")

# %%
# train, and test; while tracking the experiment
run['lr_summary'] = npt_utils.create_regressor_summary(pipeline_lr, X_train, X_test, y_train, y_test)

run['gbr_summary'] = npt_utils.create_regressor_summary(pipeline_gbr, X_train, X_test, y_train, y_test)

run['rfr_summary'] = npt_utils.create_regressor_summary(pipeline_rfr, X_train, X_test, y_train, y_test)
# Out:
# Did not log feature importance chart. Error: could not find feature importances param on Pipeline
# Did not log feature importance chart. Error: could not find feature importances param on Pipeline
# Did not log feature importance chart. Error: could not find feature importances param on Pipeline

# %%
# stop experiment
run.stop()
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 42 operations to synchronize with Neptune. Do not kill this process.
# All 42 operations synced, thanks for waiting!

# %% [markdown]
# ### Export models

# %%
# check sklearn version
from sklearn import __version__

print(__version__)

# pip install scikit-learn==0.24.1
# Out:
# 0.24.2

# %%
# loading libraries
import joblib

# Save Models to file in the model directory
# save linear regression model
joblib_lr = "model_lr.pkl"  
joblib.dump(pipeline_lr, joblib_lr)
# save random forest model
joblib_rfr = "model_rfr.pkl" 
joblib.dump(pipeline_lr, joblib_rfr)
# save gradientboost model
joblib_gbr = "model_gbr.pkl"  
joblib.dump(pipeline_lr, joblib_gbr)
# Out:
# ['model_gbr.pkl']

# %% [markdown]
# ### Recommended reading
#
# 1. https://docs.neptune.ai/integrations-and-supported-tools/model-training/sklearn
#
# 2. https://mlflow.org/docs/latest/tracking.html#scenario-1-mlflow-on-localhost
#
# 3. https://docs.neptune.ai/getting-started/examples#data-versioning
